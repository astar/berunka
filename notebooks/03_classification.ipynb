# %% [markdown]
# # Testing different classification algoritms and data sets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from pandas.tools.plotting import andrews_curves
from sklearn.grid_search import GridSearchCV
from sklearn.svm import SVC
from sklearn.cross_validation import ShuffleSplit
from sklearn import tree
pd.set_printoptions(max_rows=200, max_columns=1000)

# %%
# %pylab inline
import pylab as pl
import numpy as np

# Some nice default configuration for plots
pl.rcParams['figure.figsize'] = 10, 10
pl.rcParams['axes.grid'] = True
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# ## Data preprocessing

# %%
data = np.genfromtxt('data/archive_1_4_28072013.csv' , delimiter=',') # load 100A around Halpha

# %%
#data = np.genfromtxt('data/1_5_whole_spectrum.csv' , delimiter=',') # load whole spectrum

# %%
#data = np.genfromtxt('data/1_5_skewed_whole_spectrum.csv' , delimiter=',') # load whole spectrum

# %%
X, y = data[:,1:], data[:,0]
print("data shape: %r, target shape: %r" % (X.shape, y.shape))
print("classes: %r" % list(np.unique(y)))
# Out:
# data shape: (2164, 778), target shape: (2164,)
# classes: [1.0, 2.0, 3.0, 4.0]

# %%
n_samples, n_features = X.shape
print("n_samples=%d" % n_samples)
print("n_features=%d" % n_features)
# Out:
# n_samples=2164
# n_features=778

# %%
#X = preprocessing.scale(X)

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=1)

print("train data shape: %r, train target shape: %r"
      % (X_train.shape, y_train.shape))
print("test data shape: %r, test target shape: %r"
      % (X_test.shape, y_test.shape))
# Out:
# train data shape: (1623, 778), train target shape: (1623,)
# test data shape: (541, 778), test target shape: (541,)

# %% [markdown]
# ## SVM

# %%
clf = SVC(kernel="rbf", C=100, gamma=0.01).fit(X_train, y_train)
predicted = clf.predict(X_test)
clf.score(X_test, y_test)
# Out:
# 0.98521256931608137

# %% [markdown]
# ## Cross-validation

# %%
from sklearn.cross_validation import cross_val_score

svc = SVC(kernel="rbf", C=100, gamma=0.01)
cv = ShuffleSplit(n_samples, n_iter=10, test_size=0.1,
    random_state=0)

test_scores = cross_val_score(svc, X, y, cv=cv, n_jobs=2)
test_scores
# Out:
# array([ 0.98617512,  0.99539171,  1.        ,  0.99539171,  0.97695853,
#         0.99078341,  0.97695853,  0.98156682,  0.98617512,  0.99078341])

# %%
from scipy.stats import sem

def mean_score(scores):
    """Print the empirical mean score and standard error of the mean."""
    return ("Mean score: {0:.3f} (+/-{1:.3f})").format(
        np.mean(scores), sem(scores))

# %%
print(mean_score(test_scores))
# Out:
# Mean score: 0.988 (+/-0.002)

# %%
from sklearn import metrics
print metrics.classification_report(y_test, predicted)
# Out:
#              precision    recall  f1-score   support
#
#           1       0.98      0.96      0.97       100
#           2       0.95      0.97      0.96        72
#           3       1.00      1.00      1.00       341
#           4       0.96      0.96      0.96        28
#
# avg / total       0.99      0.99      0.99       541

# %% [markdown]
# ## DT

# %%
clf = tree.DecisionTreeClassifier().fit(X_train, y_train)
predicted = clf.predict(X_test)
clf.score(X_test, y_test)
# Out:
# 0.94639556377079481

# %%
from sklearn.cross_validation import cross_val_score

svc = tree.DecisionTreeClassifier().fit(X_train, y_train)
cv = ShuffleSplit(n_samples, n_iter=10, test_size=0.1,
    random_state=0)

test_scores = cross_val_score(svc, X, y, cv=cv, n_jobs=2)
test_scores
# Out:
# array([ 0.95852535,  0.96313364,  0.96774194,  0.94470046,  0.96313364,
#         0.92165899,  0.95391705,  0.94009217,  0.96774194,  0.95852535])

# %%
print(mean_score(test_scores))
# Out:
# Mean score: 0.954 (+/-0.005)

# %% [markdown]
# ## Plot prediction

# %%
for i, j in enumerate(np.random.permutation(X_test.shape[0])[:25]):
    pl.subplot(5, 5, (i + 1))
    pl.plot(X_test[j])
    pl.title("%d,True: %d Pred: %d" % (j, y_test[j], predicted[j]) )
    pl.xticks(()), pl.yticks(())

# %% [markdown]
# ## Plot missclasification

# %%
X_miss = X_test[y_test!=predicted]
y_miss = y_test[y_test!=predicted]
predicted_miss = predicted[y_test!=predicted]

# %%
size(np.where(y_test!=predicted))
# Out:
# 29

# %%
for i, j in enumerate(np.random.permutation(X_miss.shape[0])[:25]):
    pl.subplot(5, 5, (i + 1))
    pl.plot(X_miss[j])
    pl.title("True: %d Pred: %d" % (y_miss[j], predicted_miss[j]) )
    pl.xticks(()), pl.yticks(())
    pl.savefig('pic5.png')
    pl.savefig('pic5.svg')
    pl.savefig('pic5.pdf')
