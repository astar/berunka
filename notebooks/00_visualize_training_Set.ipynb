# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.set_printoptions(max_rows=200, max_columns=1000)

# %%
# %pylab inline
import pylab as pl
import numpy as np

# Some nice default configuration for plots
pl.rcParams['figure.figsize'] = 15, 70
pl.rcParams['axes.grid'] = True
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
data = np.genfromtxt('data/1_5_whole_spectrum.csv' , delimiter=',') # load whole spectrum

# %%
#data = data[np.where(data[:,0]==5)]

# %%
X, y = data[:,1:], data[:,0]
print("data shape: %r, target shape: %r" % (X.shape, y.shape))
print("classes: %r" % list(np.unique(y)))
# Out:
# data shape: (311, 1997), target shape: (311,)
# classes: [1.0, 5.0]

# %%
#Random 250 spectra from dataset
for i, j in enumerate(np.random.permutation(X.shape[0])[:250]):
    pl.subplot(50, 5, (i + 1))
    pl.plot(X[j])
    pl.title("idx: %d, Class: %d" % (j, y[j]) )
    pl.xticks(()), pl.yticks(())
    pl.tight_layout()
