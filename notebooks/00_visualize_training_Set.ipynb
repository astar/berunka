# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.set_printoptions(max_rows=200, max_columns=1000)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/format.py:1653: FutureWarning: set_printoptions is deprecated, use set_option instead
#   FutureWarning)

# %%
# %pylab inline
import pylab as pl
import numpy as np
import pandas as pd
# Some nice default configuration for plots
pl.rcParams['figure.figsize'] = 10, 10
pl.rcParams['axes.grid'] = True
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datafile ='../data/1_4_17_11_2013.csv'

# %%
df = pd.read_csv(datafile, header=False)

# %%
data = np.genfromtxt(datafile , delimiter=',') # load whole spectrum

# %%
#data = data[np.where(data[:,0]==5)]

# %%
X, y = data[:,1:], data[:,0]
print("data shape: %r, target shape: %r" % (X.shape, y.shape))
print("classes: %r" % list(np.unique(y)))
# Out:
# data shape: (1805, 778), target shape: (1805,)
# classes: [1.0, 2.0, 3.0, 4.0]

# %%
df_y = pd.DataFrame(y, columns=['group'])

# %%
df_y.hist()
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x3d2bb10>]], dtype=object)

# %%
g = df_y.groupby(df_y.group)

# %%
g.size()
# Out:
# group
# 1         408
# 2         289
# 3        1338
# 4         129
# dtype: int64

# %%
#Random 250 spectra from dataset
for i, j in enumerate(np.random.permutation(X.shape[0])[:25]):
    pl.subplot(5, 5, (i + 1))
    pl.plot(X[j],c='k')
    pl.title("idx: %d, Class: %d" % (j, y[j]) )
    pl.xticks(()), pl.yticks(())
    pl.tight_layout()
[pl.savefig('pic1.{}'.format(ext),dpi=600) for ext in ['png','svg','pdf']]
# Out:
# [None, None, None]
